# %% [markdown]
# # Advanced Web Scraping Lab
#
# In this lab you will first learn the following code snippet which is a simple web spider class that allows you to scrape paginated webpages. Read the code, run it, and make sure you understand how it work. In the challenges of this lab, we will guide you in building up this class so that eventually you will have a more robus web spider that you can further work on in the Web Scraping Project.

# %%
import requests
from bs4 import BeautifulSoup

class IronhackSpider:
    """
    This is the constructor class to which you can pass a bunch of parameters. 
    These parameters are stored to the class instance variables so that the
    class functions can access them later.
    
    url_pattern: the regex pattern of the web urls to scape
    pages_to_scrape: how many pages to scrape
    sleep_interval: the time interval in seconds to delay between requests. If <0, requests will not be delayed.
    content_parser: a function reference that will extract the intended info from the scraped content.
    """
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    """
    Scrape the content of a single url.
    """
    def scrape_url(self, url):
        response = requests.get(url)
        result = self.content_parser(response.content)
        self.output_results(result)
    
    """
    Export the scraped content. Right now it simply print out the results.
    But in the future you can export the results into a text file or database.
    """
    def output_results(self, r):
        print(r)
    
    """
    After the class is instantiated, call this function to start the scraping jobs.
    This function uses a FOR loop to call `scrape_url()` for each url to scrape.
    """
    def kickstart(self):
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)
            sleep_interval1(self.sleep_interval)


URL_PATTERN = 'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 1 # how many webpages to scrapge

"""
This is a custom parser function you will complete in the challenge.
Right now it simply returns the string passed to it. But in this lab
you will complete this function so that it extracts the quotes.
This function will be passed to the IronhackSpider class.
"""
def quotes_parser(content):
    return content

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, sleep_interval=1, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    > \n            \n            <a class="tag" href="/tag/change/page/1/">change</a>\n            \n            <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>\n            \n            <a class="tag" href="/tag/thinking/page/1/">thinking</a>\n            \n            <a class="tag" href="/tag/world/page/1/">world</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cIt is our choices, Harry, that show what we truly are, far more than our abilities.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">J.K. Rowling</small>\n        <a href="/author/J-K-Rowling">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="abilities,choices" /    > \n            \n            <a class="tag" href="/tag/abilities/page/1/">abilities</a>\n            \n            <a class="tag" href="/tag/choices/page/1/">choices</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThere are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    > \n            \n            <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>\n            \n            <a class="tag" href="/tag/life/page/1/">life</a>\n            \n            <a class="tag" href="/tag/live/page/1/">live</a>\n            \n            <a class="tag" href="/tag/miracle/page/1/">miracle</a>\n            \n            <a class="tag" href="/tag/miracles/page/1/">miracles</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Jane Austen</small>\n        <a href="/author/Jane-Austen">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" conten ...

# %% [markdown]
# ## Challenge 1 - Custom Parser Function
#
# In this challenge, complete the custom `quotes_parser()` function so that the returned result contains the quote string instead of the whole html page content.
#
# In the cell below, write your updated `quotes_parser()` function and kickstart the spider. Make sure the results being printed contain a list of quote strings extracted from the html content.

# %%
import sys
# !{sys.executable} -m pip install bs4 requests pandas html5lib lxml
# Out:
# Requirement already satisfied: bs4 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (0.0.1)
# Requirement already satisfied: requests in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (2.22.0)
# Requirement already satisfied: pandas in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (0.24.2)
# Requirement already satisfied: html5lib in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (1.0.1)
# Requirement already satisfied: lxml in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (4.3.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from bs4) (4.7.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from requests) (1.25.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from requests) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: pytz>=2011k in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from pandas) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.9 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\paola\appdata\local\programs\python\python37\lib\site-packages (from beautifulsoup4->bs4) (1.9.2)

# %%
# your code here
import pandas as pd


def quotes_parser2(content):
    soup_html = BeautifulSoup(content,'html')

    frase = soup_html.find_all('span',{'class':'text'})
    quote = [f.text for f in frase] 
    df = pd.DataFrame(quote)
    
    return df

# %%
my_spider2 = IronhackSpider(URL_PATTERN, 1, content_parser=quotes_parser2)
my_spider2.kickstart()
# Out:
#                                                    0
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# 4  “Imperfection is beauty, madness is genius and...
# 5  “Try not to become a man of success. Rather be...
# 6  “It is better to be hated for what you are tha...
# 7  “I have not failed. I've just found 10,000 way...
# 8  “A woman is like a tea bag; you never know how...
# 9  “A day without sunshine is like, you know, nig...

# %% [markdown]
# ## Challenge 2 - Error Handling
#
# In `IronhackSpider.scrape_url()`, catch any error that might occur when you make requests to scrape the webpage. This includes checking the response status code and catching http request errors such as timeout, SSL, and too many redirects.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
def quotes_parser2(content):    
    try:
        soup_html = BeautifulSoup(content,'html')
        frase = soup_html.find_all('span',{'class':'text'})
        quote = [f.text for f in frase] 
        df = pd.DataFrame(quote)
    except:
        print("ERROR")
    return df

my_spider2 = IronhackSpider(URL_PATTERN, 10, content_parser=quotes_parser2)
my_spider2.kickstart()
# Out:
#                                                    0
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# 4  “Imperfection is beauty, madness is genius and...
# 5  “Try not to become a man of success. Rather be...
# 6  “It is better to be hated for what you are tha...
# 7  “I have not failed. I've just found 10,000 way...
# 8  “A woman is like a tea bag; you never know how...
# 9  “A day without sunshine is like, you know, nig...
#                                                    0
# 0  “This life is what you make it. No matter what...
# 1  “It takes a great deal of bravery to stand up ...
# 2  “If you can't explain it to a six year old, yo...
# 3  “You may not be her first, her last, or her on...
# 4  “I like nonsense, it wakes up the brain cells....
# 5  “I may not have gone where I intended to go, b...
# 6  “The opposite of love is not hate, it's indiff...
# 7  “It is not a lack of love, but a lack of frien...
# 8  “Good friends, good books, and a sleepy consci...
# 9  “Life is what happens to us while we are makin...
#                                                    0
# 0  “I love you without knowing how, or when, or f...
# 1  “For every minute you are angry you lose sixty...
# 2  “If you judge people, you have no time to love...
# 3  “Anyone who thinks sitting in church can make ...
# 4  “Beauty is in the eye of the beholder and it m...
# 5  “Today you are You, that is truer than true. T...
# 6  “If you want your children to be intelligent, ...
# 7  “It is impossible to live without failing at s...
# 8  “Logic will get you from A to Z; imagination w...
# 9  “One good thing about music, when it hits you,...
#                                                    0
# 0  “The more that you read, the more things you w...
# 1  “Of course it is happening inside your head, H...
# 2  “The truth is, everyone is going to hurt you. ...
# 3  “Not all of us can do great things. But we can...
# 4  “To the well-organized mind, death is but the ...
# 5  “All you need is love. But a little chocolate ...
# 6                 “We read to know we're not alone.”
# 7   “Any fool can know. The point is to understand.”
# 8  “I have always imagined that Paradise will be ...
# 9  “It is never too late to be what you might hav...
#                                                    0
# 0  “A reader lives a thousand lives before he die...
# 1  “You can never get a cup of tea large enough o...
# 2  “You believe lies so you eventually learn to t...
# 3  “If you can make a woman laugh, you can make h...
# 4  “Life is like riding a bicycle. To keep your b...
# 5  “The real lover is the man who can thrill you ...
# 6  “A wise girl kisses but doesn't love, listens ...
# 7      “Only in the darkness can you see the stars.”
# 8  “It matters not what someone is born, but what...
# 9  “Love does not begin and end the way we seem t...
#                                                    0
# 0  “There is nothing I would not do for those who...
# 1          “Do one thing every day that scares you.”
# 2  “I am good, but not an angel. I do sin, but I ...
# 3  “If I were not a physicist, I would probably b...
# 4  “If you only read the books that everyone else...
# 5  “The difference between genius and stupidity i...
# 6                 “He's like a drug for you, Bella.”
# 7           “There is no friend as loyal as a book.”
# 8  “When one door of happiness closes, another op...
# 9  “Life isn't about finding yourself. Life is ab...
#                                                    0
# 0  “That's the problem with drinking, I thought, ...
# 1  “You don’t forget the face of the person who w...
# 2  “Remember, we're madly in love, so it's all ri...
# 3  “To love at all is to be vulnerable. Love anyt...
# 4               “Not all those who wander are lost.”
# 5  “Do not pity the dead, Harry. Pity the living,...
# 6  “There is nothing to writing. All you do is si...
# 7  “Finish each day and be done with it. You have...
# 8  “I have never let my schooling interfere with ...
# 9  “I have heard there are troubles of more than ...
#                                                    0
# 0  “If I had a flower for every time I thought of...
# 1  “Some people never go crazy. What truly horrib...
# 2  “The trouble with having an open mind, of cour...
# 3  “Think left and think right and think low and ...
# 4  “What really knocks me out is a book that, whe...
# 5  “The reason I talk to myself is because I’m th...
# 6  “You may say I'm a dreamer, but I'm not the on...
# 7  “I am free of all prejudice. I hate everyone e...
# 8  “The question isn't who is going to let me; it...
# 9  “′Classic′ - a book which people praise and do...
#                                                    0
# 0  “Anyone who has never made a mistake has never...
# 1  “A lady's imagination is very rapid; it jumps ...
# 2  “Remember, if the time should come when you ha...
# 3  “I declare after all there is no enjoyment lik...
# 4  “There are few people whom I really love, and ...
# 5  “Some day you will be old enough to start read...
# 6  “We are not necessarily doubting that God will...
# 7  “The fear of death follows from the fear of li...
# 8  “A lie can travel half way around the world wh...
# 9  “I believe in Christianity as I believe that t...
#                                                    0
# 0  “The truth." Dumbledore sighed. "It is a beaut...
# 1  “I'm the one that's got to die when it's time ...
# 2         “To die will be an awfully big adventure.”
# 3  “It takes courage to grow up and become who yo...
# 4  “But better to get hurt by the truth than comf...
# 5  “You never really understand a person until yo...
# 6  “You have to write the book that wants to be w...
# 7  “Never tell the truth to people who are not wo...
# 8        “A person's a person, no matter how small.”
# 9  “... a mind needs books as a sword needs a whe...

# %% [markdown]
# # Challenge 3 - Sleep Interval
#
# In `IronhackSpider.kickstart()`, implement `sleep_interval`. You will check if `self.sleep_interval` is larger than 0. If so, tell the FOR loop to sleep the given amount of time before making the next request.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
import time
def sleep_interval1(sleep):
    if sleep>0:
        time.sleep(sleep)

# %% [markdown]
# # Challenge 4 - Test Batch Scraping
#
# Change the `PAGES_TO_SCRAPE` value from `1` to `10`. Try if your code still works as intended to scrape 10 webpages. If there are errors in your code, fix them.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
my_spider2 = IronhackSpider(URL_PATTERN, 10, 5, content_parser=quotes_parser2)
my_spider2.kickstart()
# Out:
#                                                    0
# 0  “The world as we have created it is a process ...
# 1  “It is our choices, Harry, that show what we t...
# 2  “There are only two ways to live your life. On...
# 3  “The person, be it gentleman or lady, who has ...
# 4  “Imperfection is beauty, madness is genius and...
# 5  “Try not to become a man of success. Rather be...
# 6  “It is better to be hated for what you are tha...
# 7  “I have not failed. I've just found 10,000 way...
# 8  “A woman is like a tea bag; you never know how...
# 9  “A day without sunshine is like, you know, nig...
#                                                    0
# 0  “This life is what you make it. No matter what...
# 1  “It takes a great deal of bravery to stand up ...
# 2  “If you can't explain it to a six year old, yo...
# 3  “You may not be her first, her last, or her on...
# 4  “I like nonsense, it wakes up the brain cells....
# 5  “I may not have gone where I intended to go, b...
# 6  “The opposite of love is not hate, it's indiff...
# 7  “It is not a lack of love, but a lack of frien...
# 8  “Good friends, good books, and a sleepy consci...
# 9  “Life is what happens to us while we are makin...
#                                                    0
# 0  “I love you without knowing how, or when, or f...
# 1  “For every minute you are angry you lose sixty...
# 2  “If you judge people, you have no time to love...
# 3  “Anyone who thinks sitting in church can make ...
# 4  “Beauty is in the eye of the beholder and it m...
# 5  “Today you are You, that is truer than true. T...
# 6  “If you want your children to be intelligent, ...
# 7  “It is impossible to live without failing at s...
# 8  “Logic will get you from A to Z; imagination w...
# 9  “One good thing about music, when it hits you,...
#                                                    0
# 0  “The more that you read, the more things you w...
# 1  “Of course it is happening inside your head, H...
# 2  “The truth is, everyone is going to hurt you. ...
# 3  “Not all of us can do great things. But we can...
# 4  “To the well-organized mind, death is but the ...
# 5  “All you need is love. But a little chocolate ...
# 6                 “We read to know we're not alone.”
# 7   “Any fool can know. The point is to understand.”
# 8  “I have always imagined that Paradise will be ...
# 9  “It is never too late to be what you might hav...
#                                                    0
# 0  “A reader lives a thousand lives before he die...
# 1  “You can never get a cup of tea large enough o...
# 2  “You believe lies so you eventually learn to t...
# 3  “If you can make a woman laugh, you can make h...
# 4  “Life is like riding a bicycle. To keep your b...
# 5  “The real lover is the man who can thrill you ...
# 6  “A wise girl kisses but doesn't love, listens ...
# 7      “Only in the darkness can you see the stars.”
# 8  “It matters not what someone is born, but what...
# 9  “Love does not begin and end the way we seem t...
#                                                    0
# 0  “There is nothing I would not do for those who...
# 1          “Do one thing every day that scares you.”
# 2  “I am good, but not an angel. I do sin, but I ...
# 3  “If I were not a physicist, I would probably b...
# 4  “If you only read the books that everyone else...
# 5  “The difference between genius and stupidity i...
# 6                 “He's like a drug for you, Bella.”
# 7           “There is no friend as loyal as a book.”
# 8  “When one door of happiness closes, another op...
# 9  “Life isn't about finding yourself. Life is ab...
#                                                    0
# 0  “That's the problem with drinking, I thought, ...
# 1  “You don’t forget the face of the person who w...
# 2  “Remember, we're madly in love, so it's all ri...
# 3  “To love at all is to be vulnerable. Love anyt...
# 4               “Not all those who wander are lost.”
# 5  “Do not pity the dead, Harry. Pity the living,...
# 6  “There is nothing to writing. All you do is si...
# 7  “Finish each day and be done with it. You have...
# 8  “I have never let my schooling interfere with ...
# 9  “I have heard there are troubles of more than ...
#                                                    0
# 0  “If I had a flower for every time I thought of...
# 1  “Some people never go crazy. What truly horrib...
# 2  “The trouble with having an open mind, of cour...
# 3  “Think left and think right and think low and ...
# 4  “What really knocks me out is a book that, whe...
# 5  “The reason I talk to myself is because I’m th...
# 6  “You may say I'm a dreamer, but I'm not the on...
# 7  “I am free of all prejudice. I hate everyone e...
# 8  “The question isn't who is going to let me; it...
# 9  “′Classic′ - a book which people praise and do...
#                                                    0
# 0  “Anyone who has never made a mistake has never...
# 1  “A lady's imagination is very rapid; it jumps ...
# 2  “Remember, if the time should come when you ha...
# 3  “I declare after all there is no enjoyment lik...
# 4  “There are few people whom I really love, and ...
# 5  “Some day you will be old enough to start read...
# 6  “We are not necessarily doubting that God will...
# 7  “The fear of death follows from the fear of li...
# 8  “A lie can travel half way around the world wh...
# 9  “I believe in Christianity as I believe that t...
#                                                    0
# 0  “The truth." Dumbledore sighed. "It is a beaut...
# 1  “I'm the one that's got to die when it's time ...
# 2         “To die will be an awfully big adventure.”
# 3  “It takes courage to grow up and become who yo...
# 4  “But better to get hurt by the truth than comf...
# 5  “You never really understand a person until yo...
# 6  “You have to write the book that wants to be w...
# 7  “Never tell the truth to people who are not wo...
# 8        “A person's a person, no matter how small.”
# 9  “... a mind needs books as a sword needs a whe...

# %% [markdown]
# # Challenge 5 - Scrape a Different Website
#
# Update the parameters passed to the `IronhackSpider` constructor so that you coder can crawl [books.toscrape.com](http://books.toscrape.com/). You will need to use a different `URL_PATTERN` (figure out the new url pattern by yourself) and write another parser function to be passed to `IronhackSpider`.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
def quotes_parser_books(content):
    try:
        html_soup = BeautifulSoup(content,'html')
        frase = html_soup.select('h3 a')
        cita = [f.text for f in frase]
        s = pd.DataFrame(cita)
    except:
        print("ERROR")
    return s

URL_PATTERN_2 = 'http://books.toscrape.com/catalogue/page-%s.html'

my_spider2 = IronhackSpider(URL_PATTERN_2, 10, 0, content_parser=quotes_parser_books)
my_spider2.kickstart()
# Out:
#                                         0
# 0                      A Light in the ...
# 1                      Tipping the Velvet
# 2                              Soumission
# 3                           Sharp Objects
# 4            Sapiens: A Brief History ...
# 5                         The Requiem Red
# 6            The Dirty Little Secrets ...
# 7                 The Coming Woman: A ...
# 8                     The Boys in the ...
# 9                         The Black Maria
# 10  Starving Hearts (Triangular Trade ...
# 11                  Shakespeare's Sonnets
# 12                            Set Me Free
# 13    Scott Pilgrim's Precious Little ...
# 14                      Rip it Up and ...
# 15                  Our Band Could Be ...
# 16                                   Olio
# 17        Mesaerion: The Best Science ...
# 18           Libertarianism for Beginners
# 19                It's Only the Himalayas
#                                         0
# 0                             In Her Wake
# 1                         How Music Works
# 2       Foolproof Preserving: A Guide ...
# 3              Chase Me (Paris Nights ...
# 4                              Black Dust
# 5                Birdsong: A Story in ...
# 6   America's Cradle of Quarterbacks: ...
# 7           Aladdin and His Wonderful ...
# 8   Worlds Elsewhere: Journeys Around ...
# 9                          Wall and Piece
# 10             The Four Agreements: A ...
# 11           The Five Love Languages: ...
# 12                      The Elephant Tree
# 13                   The Bear and the ...
# 14                         Sophie's World
# 15                            Penny Maybe
# 16      Maude (1883-1993):She Grew Up ...
# 17                    In a Dark, Dark ...
# 18                    Behind Closed Doors
# 19                You can't bury them ...
#                                          0
# 0             Slow States of Collapse: ...
# 1                    Reasons to Stay Alive
# 2              Private Paris (Private #10)
# 3          #HigherSelfie: Wake Up Your ...
# 4          Without Borders (Wanderlove #1)
# 5                         When We Collided
# 6                 We Love You, Charlie ...
# 7   Untitled Collection: Sabbath Poems ...
# 8             Unseen City: The Majesty ...
# 9                           Unicorn Tracks
# 10     Unbound: How Eight Technologies ...
# 11          Tsubasa: WoRLD CHRoNiCLE 2 ...
# 12               Throwing Rocks at the ...
# 13                         This One Summer
# 14                                  Thirst
# 15                The Torch Is Passed: ...
# 16           The Secret of Dreadwillow ...
# 17            The Pioneer Woman Cooks: ...
# 18                     The Past Never Ends
# 19              The Natural History of ...
#                                       0
# 0            The Nameless City (The ...
# 1             The Murder That Never ...
# 2           The Most Perfect Thing: ...
# 3    The Mindfulness and Acceptance ...
# 4        The Life-Changing Magic of ...
# 5   The Inefficiency Assassin: Time ...
# 6         The Gutsy Girl: Escapades ...
# 7     The Electric Pencil: Drawings ...
# 8            The Death of Humanity: ...
# 9        The Bulletproof Diet: Lose ...
# 10                       The Art Forger
# 11               The Age of Genius: ...
# 12            The Activist's Tao Te ...
# 13        Spark Joy: An Illustrated ...
# 14                          Soul Reader
# 15                             Security
# 16             Saga, Volume 6 (Saga ...
# 17             Saga, Volume 5 (Saga ...
# 18  Reskilling America: Learning to ...
# 19              Rat Queens, Vol. 3: ...
#                                                  0
# 0           Princess Jellyfish 2-in-1 Omnibus, ...
# 1          Princess Between Worlds (Wide-Awake ...
# 2                          Pop Gun War, Volume ...
# 3   Political Suicide: Missteps, Peccadilloes, ...
# 4                                         Patience
# 5                           Outcast, Vol. 1: A ...
# 6              orange: The Complete Collection ...
# 7                    Online Marketing for Busy ...
# 8                              On a Midnight Clear
# 9                                Obsidian (Lux #1)
# 10                   My Paris Kitchen: Recipes ...
# 11                               Masks and Shadows
# 12             Mama Tried: Traditional Italian ...
# 13             Lumberjanes, Vol. 2: Friendship ...
# 14                 Lumberjanes, Vol. 1: Beware ...
# 15                       Lumberjanes Vol. 3: A ...
# 16              Layered: Baking, Building, and ...
# 17                        Judo: Seven Steps to ...
# 18                                            Join
# 19                           In the Country We ...
#                                            0
# 0         Immunity: How Elie Metchnikoff ...
# 1                 I Hate Fairyland, Vol. ...
# 2                            I am a Hero ...
# 3                   How to Be Miserable: ...
# 4              Her Backup Boyfriend (The ...
# 5                     Giant Days, Vol. 2 ...
# 6               Forever and Forever: The ...
# 7                  First and First (Five ...
# 8             Fifty Shades Darker (Fifty ...
# 9   Everydata: The Misinformation Hidden ...
# 10                      Don't Be a Jerk: ...
# 11                      Danganronpa Volume 1
# 12             Crown of Midnight (Throne ...
# 13         Codename Baboushka, Volume 1: ...
# 14                             Camp Midnight
# 15                  Call the Nurse: True ...
# 16                                   Burning
# 17                                Bossypants
# 18                 Bitch Planet, Vol. 1: ...
# 19           Avatar: The Last Airbender: ...
#                                        0
# 0             Algorithms to Live By: ...
# 1                 A World of Flavor: ...
# 2                    A Piece of Sky, ...
# 3                       A Murder in Time
# 4                 A Flight of Arrows ...
# 5                A Fierce and Subtle ...
# 6                  A Court of Thorns ...
# 7        (Un)Qualified: How God Uses ...
# 8                   You Are What You ...
# 9   William Shakespeare's Star Wars: ...
# 10                Tuesday Nights in 1980
# 11              Tracing Numbers on a ...
# 12           Throne of Glass (Throne ...
# 13          Thomas Jefferson and the ...
# 14                  Thirteen Reasons Why
# 15                 The White Cat and ...
# 16                     The Wedding Dress
# 17                       The Vacationers
# 18                The Third Wave: An ...
# 19                          The Stranger
#                                          0
# 0                 The Shadow Hero (The ...
# 1               The Secret (The Secret ...
# 2               The Regional Office Is ...
# 3               The Psychopath Test: A ...
# 4                              The Project
# 5                    The Power of Now: ...
# 6            The Omnivore's Dilemma: A ...
# 7          The Nerdy Nummies Cookbook: ...
# 8                  The Murder of Roger ...
# 9              The Mistake (Off-Campus #2)
# 10  The Matchmaker's Playbook (Wingmen ...
# 11                 The Love and Lemons ...
# 12                  The Long Shadow of ...
# 13                         The Kite Runner
# 14                    The House by the ...
# 15           The Glittering Court (The ...
# 16                     The Girl on the ...
# 17                     The Genius of Birds
# 18                     The Emerald Mystery
# 19                  The Cookies & Cups ...
#                                     0
# 0    The Bridge to Consciousness: ...
# 1             The Artist's Way: A ...
# 2                      The Art of War
# 3                       The Argonauts
# 4      The 10% Entrepreneur: Live ...
# 5          Suddenly in Love (Lake ...
# 6            Something More Than This
# 7                     Soft Apocalypse
# 8         So You've Been Publicly ...
# 9              Shoe Dog: A Memoir ...
# 10  Shobu Samurai, Project Aryoku ...
# 11        Secrets and Lace (Fatal ...
# 12      Scarlett Epstein Hates It ...
# 13           Romero and Juliet: A ...
# 14                     Redeeming Love
# 15       Poses for Artists Volume ...
# 16          Poems That Make Grown ...
# 17                  Nightingale, Sing
# 18            Night Sky with Exit ...
# 19                       Mrs. Houdini
#                                      0
# 0                       Modern Romance
# 1        Miss Peregrine’s Home for ...
# 2   Louisa: The Extraordinary Life ...
# 3                           Little Red
# 4           Library of Souls (Miss ...
# 5             Large Print Heart of ...
# 6                     I Had a Nice ...
# 7    Hollow City (Miss Peregrine’s ...
# 8                             Grumbles
# 9            Full Moon over Noah’s ...
# 10      Frostbite (Vampire Academy #2)
# 11                     Follow You Home
# 12             First Steps for New ...
# 13    Finders Keepers (Bill Hodges ...
# 14         Fables, Vol. 1: Legends ...
# 15                   Eureka Trivia 6.0
# 16     Drive: The Surprising Truth ...
# 17      Done Rubbed Out (Reightman ...
# 18             Doing It Over (Most ...
# 19     Deliciously Ella Every Day: ...

# %% [markdown]
# # Bonus Challenge 1 - Making Your Spider Unblockable
#
# Use techniques such as randomizing user agents and referers in your requests to reduce the likelihood that your spider is blocked by websites. [Here](http://blog.adnansiddiqi.me/5-strategies-to-write-unblock-able-web-scrapers-in-python/) is a great article to learn these techniques.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here

# %% [markdown]
# # Bonus Challenge 2 - Making Asynchronous Calls
#
# Implement asynchronous calls to `IronhackSpider`. You will make requests in parallel to complete your tasks faster.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
